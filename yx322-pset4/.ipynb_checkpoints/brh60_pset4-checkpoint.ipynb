# %% [markdown]
# ## Problem Set 4
#
# **Total points (without extra credit)**: 30
#
# **Background on the policy context**: here, we're going to use two datasets to practice reshaping, merging, and regular expression patterns. Both datasets relate to the broader issue of which employers might be violating the rights of temporary guestworkers granted visas under the H-2A program. Here are some articles about potential exploitation of guestworkers by firms and inequality caused by minimal oversight:
#
# - News media coverage of labor abuses of temporary guestworkers: https://www.buzzfeednews.com/article/kenbensinger/the-pushovers
# - GAO report on labor abuses of temporary guestworkers: https://www.gao.gov/products/gao-15-154
#
# The following datasets are located in `pset4_inputdata` (need to unzip):
#
# - `jobs_clean`: a dataset of guestworker jobs posted by many employers, some of whom have been debarred (banned) from the program for labor abuses; others not debarred
# - `debar`: a dataset of employers who committed violations of labor regulations meant to protect temporary guestworkers
#
#
# You can view a codebook here: https://docs.google.com/spreadsheets/d/1rF9GJEC8pPKxipD0TsoG9DVdqz3EJ-b-BHEtyioAX7I/edit?usp=sharing

# %%
## helpful packages
import pandas as pd
import numpy as np
import random
import re
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Reshaping data (13 points total)

# %% [markdown]
# Load the following dataset stored in `pset4_inputdata`: `debar.csv`
#
# This represents employers temporarily banned from hiring workers (debar.csv); call this `debar`
#
#
# View the head()

# %%
# pd.set_option('display.max_rows', 1000)

# %%
debar = pd.read_csv("debar.csv")
debar.head()
debar
# Out:
#                    Name           City, State  \
# 0  Macky and Brad Farms            Plains, TX
# 1         Labatte Farms             Froid, MT
# 2  RB Farm Picking, Inc             Miami, FL
# 3     Abe- Nancy Froese          Seminole, TX
# 4        Quentin Schell  Towner, North Dakota
#
#                                         Violation  Start date viol_num
# 0  Impeding the Audit Process – Partial- Response   2/13/2015    viol1
# 1      Impeding the Audit Process – Non- Response   1/17/2016    viol1
# 2       Failure to respond to audit (no response)  10/26/2013    viol1
# 3             Failure to respond to audit request  11/23/2017    viol1
# 4                Non-payment of certification fee   7/22/2016    viol1
#                                      Name           City, State  \
# 0                    Macky and Brad Farms            Plains, TX
# 1                           Labatte Farms             Froid, MT
# 2                    RB Farm Picking, Inc             Miami, FL
# ...

# %% [markdown]
# ## 1.1 (1 point)
#
# Print the number of rows in `debar` versus the number of unique employer names (`Name`). Is there one row per employer or multiple rows for some employers?

# %%
debar.shape[0]
len(debar.Name.unique())
# there are 11 rows that are duplicates in some manner, "No".
# Out:
# 105
# 94

# %% [markdown]
# ## 1.2 Investigating duplicated rows (2 points)
#
# A. Create a new column in `debar`--`is_repeated`-- that tells us whether an employer (`Name`) is repeated > 1 times
#
# *Hint*: there are multiple ways to solve this but some possibilities to get the list of names that are repeated are:
# - Using value_counts() on the `Name` variable and extracting the index from that value counts
# - Using groupby to count the rows attached to one name
#
# B. Print the rows where `is_repeated == True` and interpret
#
# C. Subset to the rows where `is_repeated == True` and save that data as `mult_debar`. Print the head() and shape

# %%
# debar.Name.value_counts()
# debar.groupby("Name").count()
debar["is_repeated"] = debar.duplicated(subset=["Name"], keep=False)
debar.loc[debar["is_repeated"]==True]
mult_debar = debar.loc[debar["is_repeated"]==True]
mult_debar.sort_values(by="Name")
mult_debar.head()
mult_debar.shape
# Out:
#                                         Name       City, State  \
# 0                       Macky and Brad Farms        Plains, TX
# 9                        Autumn Hill Orchard        Groton, MA
# 14                      Macky and Brad Farms        Plains, TX
# 23                                 SRT Farms        Morton, TX
# 24                          Dove Creek Farms  Mount Vernon, TX
# 26   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 37               Rollo Farm Labor Contractor         Miami, FL
# 44               Rollo Farm Labor Contractor         Miami, FL
# 48                                 F&W Farms       Ingalls, KS
# 49                        Cisco Produce Inc.         Cairo, GA
# 52                               Mark Duncan     Roosevelt, UT
# 54                              Xavier Horne    Lyons, Georgia
# 63                              Xavier Horne    Lyons, Georgia
# 70                        Cisco Produce Inc.         Cairo, GA
# ...

# %% [markdown]
# Marking all duplicated Names shows that only employers that had more than one violation got duplicated. With 11 duplicates, each twice, gives us 22 rows here.

# %% [markdown]
# ## 1.3 Reshape mult_debar to wide to begin filtering out duplicates (4 points)
#
# You want to separate out two cases:
#
# - Cases where the repeat rows for one employer are due to duplicated data
# - Cases where the repeat rows for one employer represent repeated violations for different issues
#
# There are various ways to check duplicates in this data (eg converting `Violation` to lowercase; replacing spelled-out states with two-dig state codes)
#
# We're going to use the simple rule of:
#
# - A row is a duplicate if, within an employer (defined by Name + City, State), the Start date for each row's violation is the same
#
# To begin to check this, reshape `mult_debar` to a wide dataframe (`mult_debar_wide`) with the following columns, treating the `Name` and `City, State` as the index for the pivot:
#
# - Name
# - City, State
# - start_date_viol1
# - start_date_viol2
#
# Print the head and shape

# %%
mult_debar_wide = pd.pivot(mult_debar,
         index = ["Name", "City, State"],
         columns = "viol_num",
         values = "Start date"
        ).reset_index()

mult_debar_wide.columns = ["Name", "City, State", "start_date_viol1", "start_date_viol2"]

mult_debar_wide.head()
mult_debar_wide.shape
# Out:
#                    Name       City, State start_date_viol1 start_date_viol2
# 0   Autumn Hill Orchard        Groton, MA         7/6/2014         7/6/2014
# 1    Cisco Produce Inc.         Cairo, GA       12/10/2015       12/10/2014
# 2      Dove Creek Farms  Mount Vernon, TX         2/9/2018         2/9/2018
# 3             F&W Farms       Ingalls, KS       12/10/2014       12/10/2014
# 4  Macky and Brad Farms        Plains, TX        2/13/2015        2/13/2015
# (11, 4)

# %% [markdown]
# ## 1.4 Filter out duplicates from original debar data (6 points)
#
# A. Using `mult_debar_wide`, add a column `is_dup` that takes value of True for cases where start_date_viol1 == start_date_viol2 marking the row as a duplicate
#
# B. Going back to the original long-format data you loaded at the beginning- `debar`
#     - For employers where `is_dup == True` as indicated by your wide-format dataframe, only keep `violnum == viol1`
#     - For all other employers (so is_dup == False and ones we didnt need to check duplicates for), keep all violnum
#     - Remove the `is_repeated` column from the `debar` data
#
# **Hint**: you can complete part B without a for loop; `pd.concat` with axis = 0 (row binding) is one way
#
# Call the resulting dataframe `debar_clean` and print the shape and # of unique employer names

# %%
mult_debar_wide["is_dup"] = mult_debar_wide.start_date_viol1 == mult_debar_wide.start_date_viol2
mult_debar_wide
# Out:
#                                        Name       City, State  \
# 0                       Autumn Hill Orchard        Groton, MA
# 1                        Cisco Produce Inc.         Cairo, GA
# 2                          Dove Creek Farms  Mount Vernon, TX
# 3                                 F&W Farms       Ingalls, KS
# 4                      Macky and Brad Farms        Plains, TX
# 5                               Mark Duncan     Roosevelt, UT
# 6   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 7               Rollo Farm Labor Contractor         Miami, FL
# 8                                 SRT Farms        Morton, TX
# 9                             Sharon Mathis        Tifton, GA
# 10                             Xavier Horne    Lyons, Georgia
#
#    start_date_viol1 start_date_viol2  is_dup
# 0          7/6/2014         7/6/2014    True
# 1        12/10/2015       12/10/2014   False
# 2          2/9/2018         2/9/2018    True
# ...

# %%
simple = debar.drop_duplicates(subset="Name", keep=False, inplace=False)

keep_both = set(mult_debar_wide[mult_debar_wide["is_dup"] == False].Name)
keep_one  = set(mult_debar_wide[mult_debar_wide["is_dup"] == True].Name)

kept_both = debar[debar["Name"].isin(keep_both)]
kept_one = debar[(debar["Name"].isin(keep_one)) & (debar["viol_num"] == "viol1")]

debar_clean = pd.concat([simple, kept_both, kept_one])
debar_clean.drop("is_repeated", axis="columns", inplace=True)
debar_clean.shape
debar_clean.Name.nunique()
# Out:
# (97, 5)
# 94

# %% [markdown]
# # 2. Merging and regex (17 points total)

# %% [markdown]
# ## 2.1 Load data on job postings
#
# The previous dataset contains a small subset of employers who faced temporary bans due to violations of H-2A program regulations
#
# Since most of the bans have expired, we're going to see which of those employers posted new H-2A jobs in the first quarter of 2021
#
# Loading the `jobs_clean.csv` data stored in `pset4_inputdata`

# %%
jobs_clean = pd.read_csv("jobs_clean.csv")
jobs_clean
# Out:
#              CASE_NUMBER                       EMPLOYER_NAME   EMPLOYER_CITY  \
# 0     H-300-20199-721302  Fazio Farms Operating Company, LLC        Portland
# 1     H-300-20231-773906                  Charlie Sunderland     McMinnville
# 2     H-300-20231-774123                   Michael Rudebusch      Livingston
# 3     H-300-20231-774151                        Lodahl Farms        Brockton
# 4     H-300-20231-774508             Dunson Harvesting, Inc.    Winter Haven
# ...                  ...                                 ...             ...
# 2715  H-300-20351-963307                   James L Schneller         Oakland
# 2716  H-300-20351-963399                     Stephen G Myers          Elkton
# 2717  H-300-20351-964097                          Andy Povey  American Falls
# 2718  H-300-20351-965435              Silver Creek Seed, LLC        Bellevue
# 2719  H-300-20352-967311                      Halabura Farms      Orwigsburg
#
# ...

# %% [markdown]
# ##  2.2 Try inner join on employer name  (2 points)
#
# - Use the `EMPLOYER_NAME` field of the `jobs` dataset
# - Use the `Name` field of the `debar_clean` dataset
#
# A. Use pd.merge with an inner join on those fields to see whether there are any exact matches.
#
# B. If there are exact matches, print the row(s) with exact matches

# %%
cases = pd.merge(debar_clean, jobs_clean, how='inner', left_on="Name", right_on="EMPLOYER_NAME")
cases
# Out:
#              Name       City, State                         Violation  \
# 0  Rafael Barajas  Sebring, Florida  Non-payment of certification fee
#
#   Start date viol_num         CASE_NUMBER   EMPLOYER_NAME   EMPLOYER_CITY  \
# 0  9/23/2016    viol1  H-300-20287-876656  Rafael Barajas  Port St. Lucie
#
#   EMPLOYER_STATE   EMPLOYER_ADDRESS_1
# 0             FL  2598 SW Dalpina Rd.

# %% [markdown]
# ## 2.3 Targeted regex (10 points total)
#
# You want to see if you can increase the exact match rate with some basic cleaning of each
# of the employer name fields in each dataset

# %% [markdown]
# ### 2.3.1 Converting to upper (2 points)
#
# A. Convert the `EMPLOYER_NAME` and `Name` fields to uppercase using list comprehension rather than df.varname.str.upper() (it's fine to do a separate list comprehension line for each of the two columns)
#
# B. Print a random sample of 15 values of each result
#
# C. Assign the full vector of uppercase names back to the original data, writing over the original `EMPLOYER_NAME` and `Name` columns

# %%
jc = [x.upper() for x in jobs_clean.EMPLOYER_NAME]
dc = [str(x).upper() for x in debar_clean.Name]
jobs_clean.EMPLOYER_NAME.sample(15)
debar_clean.Name.sample(15)
jobs_clean["EMPLOYER_NAME"] = jc
debar_clean["Name"] = dc
# Out:
# 1764              Forrest Arthur Ranch
# 1936                 Pratt Creek Ranch
# 2458                    WARD FARMS LLC
# 1925                      Britton Bina
# 1110               Roughrice Farms LLC
# 2106                     Chad Holbrook
# 44                McCabe Joint Venture
# 2652                       Noble Farms
# 1887                     S. David Earl
# 1731    Lindskov-Thiel Charolais Ranch
# 2011            Percy J. Fontenot, Inc
# 1030                         D&L Farms
# 2674                   Stephen Kraemer
# 574                Van Zyverden, Inc.
# 1277           North Texas Farms , Inc
# Name: EMPLOYER_NAME, dtype: object
# 73             Alteric Jean-Charles
# 89                      Delia Rojas
# 94             Landmark Landscaping
# 97                      Mark Duncan
# 70               Cisco Produce Inc.
# 47                      Irish Flats
# 51                Cira Cortez Lopez
# 17                   Rafael Barajas
# 40              Vern Stratton Farms
# ...

# %% [markdown]
# ### 2.3.2 Cleaning up punctuation (4 points)
#
# You notice that INC, CO, and LLC are sometimes followed by a period (.) but sometimes not
#
# A. For each dataset, write a regex pattern using `re.sub` to remove the . but only if it's preceded by INC, LLC, or CO
#
# Make sure LLC, INC, CO remain part of the string but just without the dot
#
# B. Test the pattern on the positive and negative example we provide below and print the result. See the Github issue for examples of what to return
#
#
# **Hint**: https://stackoverflow.com/questions/7191209/python-re-sub-replace-with-matched-content

# %%
pos_example_1 = "CISCO PRODUCE INC."
pos_example_2 = "AVOYELLES HONEY CO., LLC"
neg_example = "E.V. RANCH LLP"

# %%
dotter = r"(\sINC|\sLLC|\sCO)(\.)"

re.sub(dotter, r"\1", pos_example_1)
re.sub(dotter, r"\1", pos_example_2)
re.sub(dotter, r"\1", neg_example)
# Out:
# 'CISCO PRODUCE INC'
# 'AVOYELLES HONEY CO, LLC'
# 'E.V. RANCH LLP'

# %% [markdown]
# ### 2.3.3 (4 points)
#
# Use that pattern in conjunction with `re.sub` and list comprehension to clean the employer name columns in each dataset. Save the new columns as `name_clean` in each. Then, use row subsetting to (1) subset to rows that changed names and (2) for:
#
# - `debar_clean` print the `Name` and `name_clean` columns
# - `jobs_clean` print the `EMPLOYER_NAME` and `name_clean` columns
#
# Make sure to use the uppercase versions of the variables

# %%
debar_clean["name_clean"] = [re.sub(dotter, r"\1", x) for x in debar_clean.Name]
jobs_clean["name_clean"] = [re.sub(dotter, r"\1", x) for x in jobs_clean.EMPLOYER_NAME]

# %%
X = debar_clean["Name"] != debar_clean["name_clean"]
debar_clean[X][["Name", "name_clean"]]

Y = jobs_clean["EMPLOYER_NAME"] != jobs_clean["name_clean"]
jobs_clean[Y][["EMPLOYER_NAME", "name_clean"]]
# Out:
#                                 Name                       name_clean
# 15             ANTON FERTILIZER INC.             ANTON FERTILIZER INC
# 18          ALTENDORF TRANSPORT INC.          ALTENDORF TRANSPORT INC
# 20  GREAT PLAINS FLUID SERVICE, INC.  GREAT PLAINS FLUID SERVICE, INC
# 21                     REIMER'S INC.                     REIMER'S INC
# 31                     REIMER’S INC.                     REIMER’S INC
# 53                       PROMAX INC.                       PROMAX INC
# 61      SAXTONS RIVER ORCHARDS, INC.      SAXTONS RIVER ORCHARDS, INC
# 76          AVOYELLES HONEY CO., LLC          AVOYELLES HONEY CO, LLC
# 78                GERONIMO SHEEP CO.                GERONIMO SHEEP CO
# 49                CISCO PRODUCE INC.                CISCO PRODUCE INC
# 70                CISCO PRODUCE INC.                CISCO PRODUCE INC
#                                  EMPLOYER_NAME  \
# 4                      DUNSON HARVESTING, INC.
# ...

# %% [markdown]
# ## 2.4 More joins and more cleaning (5 points)
#
# A. Conduct another inner join between `jobs_clean` and `debar_clean` now using the `name_clean` column; print the result. Did the cleaning result in any more employers matched between the two datasets?
#
# B. Create a new column in `debar_clean` called `name_clean_2` that uses regex to take the following name in that dataset:
#
# - `SLASH E.V. RANCH LLP` in the `debar_clean` dataset
#
# And cleans it up so that it matches with this employer in `jobs`
#
# - `SLASH EV RANCH` in the `jobs` dataset
#
# Eg a pattern to remove the dots in the EV and the space+LLP-- you can apply the pattern to all employer names in debar_clean (so don't need to worry about only applying it to that one employer)
#
#
# C. Conduct a left join using `name_clean_2` as the join column where the left hand dataframe is `jobs_clean`; right hand dataframe is `debar_clean`, store the result as a dataframe, and print the rows where the merge indicator indicates the row was found in both dataframe
#
# **Note**: this manual cleaning process is inefficient and helps motivate the fuzzy matching we'll cover in a future week or optional OH; that fuzzy matching would recognize that Slash EV ranch is a highly similar string to slash ev ranch llp and match them without us needing to use regex to make the strings identical

# %%
pd.merge(jobs_clean, debar_clean, how='inner', on='name_clean')
#No, still only matched "RAFAEL BARAJAS"
debar_clean["name_clean_2"] = [re.sub("SLASH E.V. RANCH LLP", "SLASH EV RANCH", x) for x in debar_clean["name_clean"]]

matchies = pd.merge(jobs_clean, debar_clean,
         how='left', 
         left_on='name_clean',
         right_on='name_clean_2',
         indicator=True
        )

matchies[matchies["_merge"] == "both"]
# Out:
#           CASE_NUMBER   EMPLOYER_NAME   EMPLOYER_CITY EMPLOYER_STATE  \
# 0  H-300-20287-876656  RAFAEL BARAJAS  Port St. Lucie             FL
#
#     EMPLOYER_ADDRESS_1      name_clean            Name       City, State  \
# 0  2598 SW Dalpina Rd.  RAFAEL BARAJAS  RAFAEL BARAJAS  Sebring, Florida
#
#                           Violation Start date viol_num
# 0  Non-payment of certification fee  9/23/2016    viol1
#              CASE_NUMBER   EMPLOYER_NAME   EMPLOYER_CITY EMPLOYER_STATE  \
# 791   H-300-20287-876656  RAFAEL BARAJAS  Port St. Lucie             FL
# 1115  H-300-20306-894148  SLASH EV RANCH           Rifle             CO
#
#        EMPLOYER_ADDRESS_1    name_clean_x                  Name  \
# 791   2598 SW Dalpina Rd.  RAFAEL BARAJAS        RAFAEL BARAJAS
# 1115  22593 County Road 5  SLASH EV RANCH  SLASH E.V. RANCH LLP
#
#            City, State                         Violation  Start date viol_num  \
# ...

# %% [markdown]
# # 3. Optional extra credit 1: regex to separate companies from individuals (1 point)
#
# You notice some employers in `debar_clean` have both the name of the company and the name of individual, e.g.:
#
# COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*
#
# Use the uppercase/cleaned `name_clean` in `debar_clean`
#
# A. Write a regex pattern that does the following:
#     - Captures the pattern that occurs before COMPANY if (COMPANY) is in string; so in example above, extracts COUNTY FAIR FARM
#     - Captures the pattern that occurs before INDIVIDUAL if (INDIVIDUAL) is also in string -- so in above, extracts ANDREW WILLIAMSON (so omit the "and")
#
# B. Test the pattern on `pos_example` and `neg_example`-- make sure former returns a list (if using find.all) or match object (if using re.search) with the company name and individual name separated out; make sure latter returns empty
#
# **Hints and resources**: for step A, you can either use re.search, re.match, or re.findall; don't worry about matching B&R Harvesting and Paul Cruz (Individual)
#
# - Same regex resources as above

# %%
pos_example = "COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*"
neg_example = "CISCO PRODUCE INC"

dis_com_indi=r"(.*\s)\(COMPANY\)\s\w+\s(.*\s)\(INDIVIDUAL\)"
re.findall(dis_com_indi,pos_example)
re.findall(dis_com_indi,neg_example)
# Out:
# [('COUNTY FAIR FARM ', 'ANDREW WILLIAMSON ')]
# []

# %% [markdown]
# C. Iterate over the `name_clean` column in debar and use regex to create two new columns in `debar_clean`:
#    - `co_name`: A column for company (full `name_clean` string if no match; pattern before COMPANY if one extracted)
#    - `ind_name`: A column for individual (full `name_clean` string if no match; pattern before INDIVIDUAL if one extracted)

# %%
# Define new regex
regex_com = r"(.*?)\(?(?=COMPANY)"
regex_indi = r"(.*?)\(?(?=INDIVIDUAL)"

# Define dictionary 'ind_name_dic' and 'co_name_dic'
name_clean_list = debar_clean.name_clean.astype(str).tolist()

co_name_dic = {}
ind_name_dic = {}

i = 0
j = 0
# iterate over the 'name_clean' column (company)
for name in name_clean_list:
    name_match_com = re.findall(regex_com,name)
    if len(name_match_com) != 0:
        co_name_dic[name] = name_match_com[0]
    else:
        co_name_dic[name] = name_clean_list[i]
    
    i += 1

# iterate over the 'name_clean' column (individual)
for name in name_clean_list:
    name_match_indi = re.findall(regex_indi,name)
    if len(name_match_indi) != 0:
        ind_name_dic[name] = name_match_indi[0]
    else:
        ind_name_dic[name] = name_clean_list[j]
    
    j += 1

debar_clean['co_name'] = debar_clean.name_clean.map(co_name_dic)
debar_clean['ind_name'] = debar_clean.name_clean.map(ind_name_dic)
debar_clean
# Out:
#                            Name           City, State  \
# 1                 LABATTE FARMS             Froid, MT
# 2          RB FARM PICKING, INC             Miami, FL
# 3             ABE- NANCY FROESE          Seminole, TX
# 4                QUENTIN SCHELL  Towner, North Dakota
# 5                CHRIS ROBINSON        Paint Lick, KY
# ..                          ...                   ...
# 44  ROLLO FARM LABOR CONTRACTOR             Miami, FL
# 48                    F&W FARMS           Ingalls, KS
# 81                SHARON MATHIS            Tifton, GA
# 95          AUTUMN HILL ORCHARD            Groton, MA
# 97                  MARK DUNCAN         Roosevelt, UT
#
#                                          Violation  Start date viol_num  \
# 1       Impeding the Audit Process – Non- Response   1/17/2016    viol1
# 2        Failure to respond to audit (no response)  10/26/2013    viol1
# 3              Failure to respond to audit request  11/23/2017    viol1
# ...

# %% [markdown]
#
# D. Print three columns for the rows in `debar_clean` containing the negative example and positive example described above (county fair farm and cisco produce):
#
# - `name_clean`
# - `co_name`
# - `ind_name`
# - `Violation`
#
# **Note**: as shown in the outcome there may be duplicates of the same company reflecting different violations

# %%
## D. Print
# negative example for company
debar_clean.loc[debar_clean.name_clean == debar_clean.co_name][['name_clean','co_name','Violation']].head()
# positive example for company
debar_clean.loc[debar_clean.name_clean != debar_clean.co_name][['name_clean','co_name','Violation']]

# negative example for individual
debar_clean.loc[debar_clean.name_clean == debar_clean.ind_name][['name_clean','ind_name','Violation']].head()
# positive example for individual
debar_clean.loc[debar_clean.name_clean != debar_clean.ind_name][['name_clean','ind_name','Violation']]
# Out:
#              name_clean               co_name  \
# 1         LABATTE FARMS         LABATTE FARMS
# 2  RB FARM PICKING, INC  RB FARM PICKING, INC
# 3     ABE- NANCY FROESE     ABE- NANCY FROESE
# 4        QUENTIN SCHELL        QUENTIN SCHELL
# 5        CHRIS ROBINSON        CHRIS ROBINSON
#
#                                     Violation
# 1  Impeding the Audit Process – Non- Response
# 2   Failure to respond to audit (no response)
# 3         Failure to respond to audit request
# 4            Non-payment of certification fee
# 5  Impeding the Audit Process – Non- Response
#                                            name_clean            co_name  \
# 84  COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMS...  COUNTY FAIR FARM
#
#         Violation
# 84  WHD Debarment
#              name_clean              ind_name  \
# 1         LABATTE FARMS         LABATTE FARMS
# 2  RB FARM PICKING, INC  RB FARM PICKING, INC
# 3     ABE- NANCY FROESE     ABE- NANCY FROESE
# ...

# %% [markdown]
# # 4. Optional extra credit 2 (up to 3 points)
#
# - For 1 point extra credit, create a visualization with 1+ of the existing fields in either the raw `jobs` or `debar` data. We'll be showing cool visualizations in class so use your imagination! Options could include visualizing between-state or over-time variation
#
# - For 3 points extra credit instead, geocode the employer addresses in `jobs` and plot the addresses of jobs as points overlaid on top of a map of Georgia
#     - **Note**: this extra credit involves Googling since we have not yet covered spatial data.
#         - For discussion of how to geocode addresses -> lat/long, see: https://www.natasshaselvaraj.com/a-step-by-step-guide-on-geocoding-in-python/
#         - For discussion of plotting lat/long dots against a map, see this discussion of geopandas: https://towardsdatascience.com/plotting-maps-with-geopandas-428c97295a73
#     - Relevant columns include `EMPLOYER_ADDRESS_1`
#     - The geocoding might have a long runtime so feel free to implement it in a separate .py script that you submit alongside your notebook and to just read in the geocoded data

# %%
# For Mac users:
# !pip install geopandas
# Brian's Jupyter was running in Linux and had to use this:
# %pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import googlemaps
import shapely
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
jobs_clean.EMPLOYER_ADDRESS_1

# Subset to only Georgia
jobs_GA=jobs_clean.loc[jobs_clean.EMPLOYER_STATE=='GA'].reset_index(drop=True)
jobs_GA['Address'] = jobs_GA['EMPLOYER_ADDRESS_1'] + ', ' + jobs_GA['EMPLOYER_CITY'] + ', ' + jobs_GA['EMPLOYER_STATE']
jobs_GA
# Out:
# 0                                 8433 NE 13th Ave
# 1                         982 Northcutts Cove Road
# 2                             7366 State Hwy 146 S
# 3                                   4198 Road 2049
# 4                          400 Eagle Lake Loop Rd.
#                            ...
# 2715                         1448 Little Knob Road
# 2716                         5850 W Jeff Davis Hwy
# 2717                               2412 Povey Road
# 2718    231 Tendoy Street - Note: No Mail Delivery
# 2719                             1286 Chestnut Rd.
# Name: EMPLOYER_ADDRESS_1, Length: 2720, dtype: object
#            CASE_NUMBER              EMPLOYER_NAME  EMPLOYER_CITY  \
# 0   H-300-20240-791807         MCLAIN FARMS, INC.          Lyons
# 1   H-300-20198-717939   SOUTHERN FLAVOR FARMS LP    Fort Valley
# 2   H-300-20246-802262  THEM BOYZ HARVESTING, LLC         Tifton
# 3   H-300-20246-802215  THEM BOYZ HARVESTING, LLC         Tifton
# ...

# %%
## Geocoding (key is API key we get from google)
gmaps_key = googlemaps.Client(key="AIzaSyAephUZTeaLjSDodcI4bmXgsLGxgfWrOSc")

# Geocode the entire dataframe:

def geocode(address):
    g = gmaps_key.geocode(address)
    lng = g[0]["geometry"]["location"]["lng"]
    lat = g[0]["geometry"]["location"]["lat"]
    return (lng,lat)

jobs_GA['geocoded'] = jobs_GA['Address'].apply(geocode)

# %%
jobs_GA.head()
# Out:
#           CASE_NUMBER              EMPLOYER_NAME EMPLOYER_CITY EMPLOYER_STATE  \
# 0  H-300-20240-791807         MCLAIN FARMS, INC.         Lyons             GA
# 1  H-300-20198-717939   SOUTHERN FLAVOR FARMS LP   Fort Valley             GA
# 2  H-300-20246-802262  THEM BOYZ HARVESTING, LLC        Tifton             GA
# 3  H-300-20246-802215  THEM BOYZ HARVESTING, LLC        Tifton             GA
# 4  H-300-20249-807813              AG G.R.O. LLC          Wray             GA
#
#          EMPLOYER_ADDRESS_1                 name_clean  \
# 0  534 McLain Cemetery Road          MCLAIN FARMS, INC
# 1      9465 Miami Valley Rd   SOUTHERN FLAVOR FARMS LP
# 2          30 Sand Creek Rd  THEM BOYZ HARVESTING, LLC
# 3          30 Sand Creek Rd  THEM BOYZ HARVESTING, LLC
# 4              19 Lupe Lane              AG G.R.O. LLC
#
#                                  Address                   geocoded
# 0    534 McLain Cemetery Road, Lyons, GA  (-82.2602819, 32.2718882)
# ...

# %%
# Get Georgia's map from Internet
Georgia_map = gpd.read_file('Georgia.shp')
Georgia_map.to_crs(epsg=4326).plot()
# Out:
# <AxesSubplot:>

# %%
# Define GoPandas DataFrame
crs = {'init':'EPSG:4326'}
geometry = [Point(xy) for xy in jobs_GA['geocoded']]
geo_df = gpd.GeoDataFrame(jobs_GA, 
                          crs = crs, 
                          geometry = geometry)
# Out:
# /Users/xuyetongseattle/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
geo_df[['name_clean','geometry']].head()
# Out:
#                   name_clean                    geometry
# 0          MCLAIN FARMS, INC  POINT (-82.26028 32.27189)
# 1   SOUTHERN FLAVOR FARMS LP  POINT (-83.81256 32.55391)
# 2  THEM BOYZ HARVESTING, LLC  POINT (-83.57613 31.47838)
# 3  THEM BOYZ HARVESTING, LLC  POINT (-83.57613 31.47838)
# 4              AG G.R.O. LLC  POINT (-83.05747 31.58672)

# %%
# Visualiazation
fig,ax = plt.subplots(figsize=(5,5))
Georgia_map.to_crs(epsg=4326).plot(ax=ax, color='lightgrey')
geo_df.plot(ax=ax, alpha=.8)
ax.set_title('New jobs in Georgia')
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
# Text(0.5, 1.0, 'New jobs in Georgia')
